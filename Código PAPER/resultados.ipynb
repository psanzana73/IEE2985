# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

# Directorio donde están los resultados
input_dir = "modelo/data/output"
# Directorio base donde se guardarán los gráficos
output_base_dir = "graficos_resultados"

if not os.path.exists(output_base_dir):
    os.makedirs(output_base_dir)

# Buscar todos los archivos de resultados que coincidan con el patrón
result_files = glob.glob(os.path.join(input_dir, "resultados_*.xlsx"))

print(f"Se encontraron {len(result_files)} archivos de resultados para procesar.")

for file_path in result_files:
    file_name = os.path.basename(file_path)
    scenario_name = file_name.replace("resultados_", "").replace(".xlsx", "")
    
    # Crear carpeta específica para este escenario
    scenario_output_dir = os.path.join(output_base_dir, scenario_name)
    if not os.path.exists(scenario_output_dir):
        os.makedirs(scenario_output_dir)

    print(f"\n--- Procesando: {file_name} ---")
    print(f"Guardando gráficos en: {scenario_output_dir}/")

    try:
        # Cargar hojas de Excel
        # Usamos try-except por si alguna hoja falta (ej. Frecuencia si no se calculó)
        dfs = pd.read_excel(file_path, sheet_name=None) 
        
        df_gen = dfs.get("Generadores")
        df_scc = dfs.get("Cortocircuito")
        df_freq = dfs.get("Frecuencia")

        if df_gen is None or df_scc is None:
            print(f"Advertencia: Faltan hojas críticas en {file_name}. Saltando...")
            continue

        # --- Gráfico 1: Despacho de Generación (Stacked Bar) ---
        print("Generando Gráfico 1: Despacho de Generación...")
        df_gen['generator'] = 'Gen ' + df_gen['generator'].astype(str)
        gen_pivot = df_gen.pivot_table(index='time', columns='generator', values='p', aggfunc='sum')
        gen_pivot = gen_pivot.fillna(0)
            
        plt.figure(figsize=(14, 7))
        ax = gen_pivot.plot(kind='bar', stacked=True, figsize=(14, 7), width=0.8)
        ax.set_title(f'Despacho de Generación por Hora\n({scenario_name})', fontsize=16)
        ax.set_xlabel('Hora (time)', fontsize=12)
        ax.set_ylabel('Potencia (p) [MW]', fontsize=12)
        ax.legend(title='Generador', bbox_to_anchor=(1.02, 1), loc='upper left')
        plt.xticks(rotation=45)
        ax.grid(axis='y', linestyle='--', alpha=0.7)
            
        if not gen_pivot.empty:
            if gen_pivot.index.min() == 1:
                ax.set_xticks(range(0, 24))
                ax.set_xticklabels(range(1, 25))
            else:
                ax.set_xticklabels(gen_pivot.index)
        
        plt.tight_layout(rect=[0, 0, 0.88, 1])
        plt.savefig(os.path.join(scenario_output_dir, "despacho_generacion.png"))
        plt.close()

        # --- Gráfico 2: Validación de la Restricción SCC ---
        print("Generando Gráfico 2: Validación SCC...")
        if 'I_limit_real' in df_scc.columns:
            idx_worst = df_scc.groupby('time')['I_total'].idxmin()
            df_worst = df_scc.loc[idx_worst]

            plt.figure(figsize=(14, 7))
            ax = df_worst.plot(x='time', y='I_total', marker='o', label='SCC Mínima (I_total)', color='dodgerblue', linewidth=2, figsize=(14,7))
            df_worst.plot(x='time', y='I_limit_real', marker='x', linestyle='--', label='Límite Real (I_limit_real)', color='red', linewidth=2, ax=ax)
            
            ax.set_title(f'Validación SCC: Peor Bus por Hora\n({scenario_name})', fontsize=16)
            ax.set_xlabel('Hora', fontsize=12)
            ax.set_ylabel('SCC [p.u.]', fontsize=12)
            ax.legend(fontsize=12)
            ax.grid(axis='y', linestyle='--', alpha=0.7)
            
            # Area de cumplimiento
            ax.fill_between(df_worst['time'], df_worst['I_total'], df_worst['I_limit_real'], 
                            where=(df_worst['I_total'] >= df_worst['I_limit_real']), 
                            color='green', alpha=0.1, label='Cumplimiento')
            ax.fill_between(df_worst['time'], df_worst['I_total'], df_worst['I_limit_real'], 
                            where=(df_worst['I_total'] < df_worst['I_limit_real']), 
                            color='red', alpha=0.1, label='Violación')

            plt.tight_layout()
            plt.savefig(os.path.join(scenario_output_dir, "scc_minima_sistema.png"))
            plt.close()
        else:
            print("Advertencia: Columna 'I_limit_real' no encontrada. Saltando Gráfico 2.")

        # --- Gráficos de Frecuencia (si existen datos) ---
        if df_freq is not None and not df_freq.empty:
            # Gráfico 3: Inercia
            print("Generando Gráfico 3: Inercia...")
            plt.figure(figsize=(14, 7))
            ax = df_freq.plot(x='time', y='inertia_equiv', kind='line', marker='s', color='green', linewidth=2, figsize=(14, 7))
            ax.set_title(f'Inercia Equivalente del Sistema\n({scenario_name})', fontsize=16)
            ax.set_ylabel('Inercia [MWs]', fontsize=12)
            ax.grid(axis='y', linestyle='--', alpha=0.7)
            plt.tight_layout()
            plt.savefig(os.path.join(scenario_output_dir, "inercia_sistema.png"))
            plt.close()

            # Gráfico 4: RoCoF
            print("Generando Gráfico 4: RoCoF...")
            plt.figure(figsize=(14, 7))
            plt.plot(df_freq['time'], df_freq['rocof'], marker='x', color='purple', linewidth=2, label='RoCoF')
            plt.axhline(y=0.5, color='red', linestyle='--', label='Límite (0.5 Hz/s)')
            plt.title(f'RoCoF del Sistema\n({scenario_name})', fontsize=16)
            plt.ylabel('RoCoF [Hz/s]', fontsize=12)
            plt.legend()
            plt.grid(axis='y', linestyle='--', alpha=0.7)
            plt.tight_layout()
            plt.savefig(os.path.join(scenario_output_dir, "rocof_sistema.png"))
            plt.close()

    except Exception as e:
        print(f"ERROR procesando {file_name}: {e}")

print("\n--- Proceso de graficación por lotes completado ---")
# Out:
# Cargando datos desde: modelo/data/output/resultados.xlsx
# Guardando gráficos en: graficos_resultados/
# Datos cargados exitosamente.
# Generando Gráfico 1: Despacho de Generación...
# Gráfico 1 guardado en: graficos_resultados\despacho_generacion.png
# Generando Gráfico 2: Validación de la Restricción SCC...
# Gráfico 2 guardado en: graficos_resultados\scc_minima_sistema.png
# Generando Gráfico 3: Inercia del Sistema...
# Gráfico 3 guardado en: graficos_resultados\inercia_sistema.png
# Generando Gráfico 4: RoCoF del Sistema...
# Gráfico 4 guardado en: graficos_resultados\rocof_sistema.png
#
# --- Proceso de graficación completado ---

# %% [markdown]
# Mapeo de Buses

# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import os
import numpy as np
import matplotlib.lines as mlines
import glob

# --- CONFIGURACIÓN DE RUTAS ---
output_dir_base = "modelo/data/output"
input_dir_base = "modelo/data/input"
graficos_dir_base = "graficos_resultados"

# Asegurar que el directorio base de gráficos exista
if not os.path.exists(graficos_dir_base):
    os.makedirs(graficos_dir_base)

# --- TOPOLOGÍA Y POSICIONES (Fijas) ---
edges = [
    (1, 2), (1, 3), (2, 4), (3, 4), (2, 5), (2, 6), (4, 6), (5, 7), 
    (6, 7), (6, 8), (6, 9), (6, 10), (9, 11), (9, 10), (4, 12), (12, 13), 
    (12, 14), (12, 15), (12, 16), (14, 15), (16, 17), (15, 18), (18, 19), 
    (19, 20), (10, 20), (10, 17), (10, 21), (10, 22), (21, 22), (15, 23), 
    (22, 24), (23, 24), (24, 25), (25, 26), (25, 27), (28, 27), (27, 29), 
    (27, 30), (29, 30), (8, 28), (6, 28)
]

bus_positions = {
    1: (0.1, 0.9), 2: (0.3, 0.9), 3: (0.1, 0.7), 4: (0.3, 0.7),
    5: (0.5, 0.9), 6: (0.5, 0.7), 7: (0.7, 0.9), 8: (0.7, 0.6),
    9: (0.5, 0.5), 10: (0.5, 0.3), 11: (0.6, 0.5), 12: (0.2, 0.5),
    13: (0.05, 0.5), 14: (0.05, 0.35), 15: (0.2, 0.3), 16: (0.2, 0.6),
    17: (0.4, 0.4), 18: (0.2, 0.15), 19: (0.3, 0.1), 20: (0.4, 0.1),
    21: (0.6, 0.2), 22: (0.6, 0.1), 23: (0.3, 0.0), 24: (0.45, 0.0),
    25: (0.6, 0.0), 26: (0.7, 0.0), 27: (0.8, 0.2), 28: (0.9, 0.6),
    29: (0.8, 0.1), 30: (0.9, 0.0)
}

# --- FUNCIÓN DE GRAFICACIÓN ---
def generar_mapa_scc(ruta_resultado, ruta_datos_originales, ruta_imagen_salida, titulo_escenario):
    print(f"   -> Generando mapa para: {titulo_escenario}")
    
    # 1. Cargar Datos
    try:
        df_scc = pd.read_excel(ruta_resultado, sheet_name="Cortocircuito")
        df_bus_data = pd.read_excel(ruta_datos_originales, sheet_name="BUS DATA")
    except Exception as e:
        print(f"      [ERROR] No se pudieron leer los archivos Excel: {e}")
        return

    if 'I_limit_real' not in df_scc.columns or 'I_total' not in df_scc.columns:
        print("      [ERROR] Columnas 'I_total' o 'I_limit_real' faltantes en resultados.")
        return

    # 2. Procesar Datos
    df_scc['scc_margin'] = df_scc['I_total'] - df_scc['I_limit_real']
    worst_margin_per_bus = df_scc.groupby('bus_id')['scc_margin'].min()
    scc_min_abs_per_bus = df_scc.groupby('bus_id')['I_total'].min()
    bus_type_map = pd.Series(df_bus_data.Tipo.values, index=df_bus_data.id).to_dict()

    try:
        demand_cols = [col for col in df_bus_data.columns if str(col).startswith('t') and str(col)[1:].isdigit()]
        if not demand_cols:
            df_bus_data['has_demand'] = False
        else:
            df_bus_data['has_demand'] = (df_bus_data[demand_cols].sum(axis=1) > 0)
        bus_has_demand = pd.Series(df_bus_data.has_demand.values, index=df_bus_data.id).to_dict()
    except:
        bus_has_demand = {}

    # 3. Configuración Gráfica
    G = nx.Graph()
    G.add_nodes_from(scc_min_abs_per_bus.index)
    G.add_edges_from(edges)

    # Escala de colores FIJA (2 a 10)
    cmap = plt.cm.coolwarm_r 
    v_min = 2.0
    v_max = 10.0
    norm_for_cbar = plt.Normalize(vmin=v_min, vmax=v_max)

    # 4. Dibujar
    fig, ax = plt.subplots(figsize=(20, 14))
    nx.draw_networkx_edges(G, bus_positions, ax=ax, alpha=0.5, edge_color='gray')

    bus_bar_length = 0.015
    symbol_offset = 0.05
    arrow_length = 0.05
    arrow_head_width = 0.015

    for bus_id in G.nodes():
        if bus_id not in bus_positions: continue
        
        x, y = bus_positions[bus_id]
        bus_type = bus_type_map.get(bus_id, 0)
        margin = worst_margin_per_bus.get(bus_id, 0)
        
        color = cmap(norm_for_cbar(margin))

        # Barra del bus
        ax.plot([x - bus_bar_length, x + bus_bar_length], [y, y], 
                color=color, linewidth=8, solid_capstyle='butt')

        # Generador Síncrono
        if bus_type in [1, 2]:
            gen_y = y + symbol_offset
            ax.plot(x, gen_y, marker='o', markersize=20, 
                    markerfacecolor='none', markeredgecolor='black', markeredgewidth=1.5)
            ax.text(x, gen_y, '~', fontsize=22, fontweight='bold', ha='center', va='center')
            ax.plot([x, x], [y, gen_y - 0.013], color='black', linewidth=1)

        # Generador IBG
        if bus_type == 3:
            gen_y = y + symbol_offset
            ax.plot(x, gen_y, marker='^', markersize=20, 
                    markerfacecolor='none', markeredgecolor='black', markeredgewidth=1.5)
            ax.plot([x, x], [y, gen_y - 0.015], color='black', linewidth=1)

        # Carga
        if bus_has_demand.get(bus_id, False):
            load_y_start = y - 0.005 
            load_y_end = y - arrow_length
            ax.arrow(x, load_y_start, 0, (load_y_end - load_y_start), 
                     head_width=arrow_head_width, head_length=0.02, 
                     fc='black', ec='black', length_includes_head=True)

        # Etiquetas
        scc_val = scc_min_abs_per_bus.get(bus_id, 0)
        ax.text(x + 0.02, y, str(bus_id), ha='left', va='center', fontsize=12, fontweight='bold')
        ax.text(x, y - (arrow_length + 0.02), f"{scc_val:.2f} p.u.", ha='center', va='top', fontsize=10)

    # 5. Decoración
    ax.set_title(f'Mapa de Margen de SCC (Peor Caso) - {titulo_escenario}\nEscala Fija: Rojo(≤2) - Azul(≥10)', fontsize=20)
    ax.set_xlim(-0.05, 1.05)
    ax.set_ylim(-0.1, 1.05)
    ax.axis('off')

    # Barra de color
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm_for_cbar)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, shrink=0.8, aspect=30, pad=0.01)
    cbar.set_label('Margen de SCC (I_total - I_limit_real)', fontsize=14, weight='bold')
    cbar.set_ticks([2, 4, 6, 8, 10])
    cbar.set_ticklabels(['≤ 2 (Rojo)', '4', '6', '8', '≥ 10 (Azul)'])

    # Leyenda
    bus_bar = mlines.Line2D([], [], color='gray', marker='s', linestyle='None', markersize=10, markerfacecolor='gray', label='Barra de Bus (Color por Margen SCC)')
    load_arrow = mlines.Line2D([], [], color='black', marker=r'$\downarrow$', linestyle='None', markersize=15, label='Carga (Demanda)')
    sg_icon = mlines.Line2D([], [], color='black', marker='o', linestyle='None', markersize=12, markerfacecolor='none', markeredgewidth=1.5, label='Gen. Síncrono')
    ibg_icon = mlines.Line2D([], [], color='black', marker='^', linestyle='None', markersize=12, markerfacecolor='none', markeredgewidth=1.5, label='Gen. IBG (Eólico)')
    
    ax.legend(handles=[bus_bar, load_arrow, sg_icon, ibg_icon], loc='lower left', fontsize=12, title="Simbología")

    # Guardar
    plt.savefig(ruta_imagen_salida, bbox_inches='tight')
    plt.close()
    print(f"      [OK] Guardado en: {ruta_imagen_salida}")


# --- BUCLE PRINCIPAL ---
print("Iniciando generación masiva de mapas SCC (Sin carpetas)...")

result_files = glob.glob(os.path.join(output_dir_base, "resultados_*.xlsx"))

for res_file in result_files:
    filename = os.path.basename(res_file)
    
    try:
        # Deducir nombre del archivo de entrada original
        base_part = filename.replace("resultados_", "")
        idx_req = base_part.rfind("_ReqSCC") 
        idx_ipu = base_part.rfind("_Ipu") 

        if idx_req != -1:
            input_name = base_part[:idx_req]
        elif idx_ipu != -1:
            input_name = base_part[:idx_ipu]
        else:
            input_name = base_part.replace(".xlsx", "")
            
        input_file_path = os.path.join(input_dir_base, f"{input_name}.xlsx")
        
        if not os.path.exists(input_file_path):
            print(f"\n[ADVERTENCIA] No se encontró entrada para {filename}.")
            continue

        # MODIFICACIÓN: Definir nombre de archivo único en lugar de carpeta
        scenario_name = filename.replace(".xlsx", "")
        output_image_name = f"scc_mapa_sld_{scenario_name}.png"
        output_image_path = os.path.join(graficos_dir_base, output_image_name)
        
        generar_mapa_scc(res_file, input_file_path, output_image_path, scenario_name)

    except Exception as e:
        print(f"Error procesando {filename}: {e}")

print("\n--- Proceso completado ---")
# Out:
# Iniciando generación masiva de mapas SCC (Sin carpetas)...
#    -> Generando mapa para: resultados_datos_finales30_pen20_ReqSCC0.0
#       [OK] Guardado en: graficos_resultados\scc_mapa_sld_resultados_datos_finales30_pen20_ReqSCC0.0.png
#    -> Generando mapa para: resultados_datos_finales30_pen20_ReqSCC2.0
#       [OK] Guardado en: graficos_resultados\scc_mapa_sld_resultados_datos_finales30_pen20_ReqSCC2.0.png
#    -> Generando mapa para: resultados_datos_finales30_pen20_ReqSCC3.0
#       [OK] Guardado en: graficos_resultados\scc_mapa_sld_resultados_datos_finales30_pen20_ReqSCC3.0.png
#    -> Generando mapa para: resultados_datos_finales30_pen50_ReqSCC0.0
#       [OK] Guardado en: graficos_resultados\scc_mapa_sld_resultados_datos_finales30_pen50_ReqSCC0.0.png
#    -> Generando mapa para: resultados_datos_finales30_pen50_ReqSCC2.0
#       [OK] Guardado en: graficos_resultados\scc_mapa_sld_resultados_datos_finales30_pen50_ReqSCC2.0.png
# ...
